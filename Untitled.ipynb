# %%
import pandas as pd
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("/Users/HustlersParadise/Desktop/FPA_FOD_20170508.sqlite")
df = pd.read_sql_query("SELECT * from Fires", con)

# Verify that result of SQL query is stored in the dataframe
print(df.head())

con.close()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# ...

# %%
df['ZIP'].head()
# Out:
# 0    63
# 1    61
# 2    17
# 3     3
# 4     3
# Name: COUNTY, dtype: object

# %%
df.head(3000)
# Out:
#       OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0            1       1  FS-1418826                FED   FS-FIRESTAT
# 1            2       2  FS-1418827                FED   FS-FIRESTAT
# 2            3       3  FS-1418835                FED   FS-FIRESTAT
# 3            4       4  FS-1418845                FED   FS-FIRESTAT
# 4            5       5  FS-1418847                FED   FS-FIRESTAT
# 5            6       6  FS-1418849                FED   FS-FIRESTAT
# 6            7       7  FS-1418851                FED   FS-FIRESTAT
# 7            8       8  FS-1418854                FED   FS-FIRESTAT
# 8            9       9  FS-1418856                FED   FS-FIRESTAT
# 9           10      10  FS-1418859                FED   FS-FIRESTAT
# 10          11      11  FS-1418861                FED   FS-FIRESTAT
# 11          12      12  FS-1418863                FED   FS-FIRESTAT
# 12          13      13  FS-1418865                FED   FS-FIRESTAT
# ...

# %%
API_Keys = ['74cb0776a68549e6a1e35942202302', 'cb75f443803149f88a440152202302', '5c44e0e4b67546fd85540157202302' , '8816059be77e4136a7340317202302','61600e44ce0245f29b440504202302', 'd3ff1670c43d4f688d940554202302']

# %%
def callapi(city_ID,country_code,start_date,end_date,YOUR_API_KEY,state):
    frequency = 24
    api_key = YOUR_API_KEY
    location_list = [f'{state}']
    hist_weather_data = retrieve_hist_data(api_key,
                                    location_list,
                                    start_date,
                                    end_date,
                                    frequency,
                                    location_label = False,
                                    export_csv = True,
                                    store_df = True)

# %%
for key in API_Keys:
    callapi()
# Out:
# [             date_time maxtempC mintempC totalSnow_cm sunHour uvIndex uvIndex  \
#  0  2018-12-11 00:00:00       32       26          0.0    10.2       1       1
#  1  2018-12-11 03:00:00       32       26          0.0    10.2       1       1
#  2  2018-12-11 06:00:00       32       26          0.0    10.2       1       1
#  3  2018-12-11 09:00:00       32       26          0.0    10.2       1       1
#  4  2018-12-11 12:00:00       32       26          0.0    10.2       1       1
#  5  2018-12-11 15:00:00       32       26          0.0    10.2       1       1
#  6  2018-12-11 18:00:00       32       26          0.0    10.2       1       1
#  7  2018-12-11 21:00:00       32       26          0.0    10.2       1       1
#  0  2018-12-12 00:00:00       29       26          0.0    10.3       1       1
#  1  2018-12-12 03:00:00       29       26          0.0    10.3       1       1
#  2  2018-12-12 06:00:00       29       26          0.0    10.3       1       1
# ...

# %%
#!pip install wwo-hist
from wwo_hist import retrieve_hist_data
import os
os.chdir("./")

# %%
# Out:
# Retrieving weather data for singapore
#
#
# Currently retrieving data for singapore: from 2018-12-11 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.282521
# Currently retrieving data for singapore: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.851280
# Currently retrieving data for singapore: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.480669
# Currently retrieving data for singapore: from 2019-03-01 to 2019-03-11
# Time elapsed (hh:mm:ss.ms) 0:00:05.348533
#
#
# export singapore completed!
#
#
#
#
# Retrieving weather data for california
#
#
# Currently retrieving data for california: from 2018-12-11 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.407141
# Currently retrieving data for california: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.146497
# Currently retrieving data for california: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.681064
# ...
